# %%
import pandas as pd
import numpy as np
df=pd.read_excel('/content/auto-mpg .xlsx')

# %%
df
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18          8         307.0         130    3504          12.0
# 1    15          8         350.0         165    3693          11.5
# 2    18          8         318.0         150    3436          11.0
# 3    16          8         304.0         150    3433          12.0
# 4    17          8         302.0         140    3449          10.5
# ..  ...        ...           ...         ...     ...           ...
# 93   14          8         318.0         150    4237          14.5
# 94   13          8         440.0         215    4735          11.0
# 95   12          8         455.0         225    4951          11.0
# 96   13          8         360.0         175    3821          11.0
# 97   18          6         225.0         105    3121          16.5
#
#     model year  origin                      car name CAR Number
# 0         70.0       1     chevrolet chevelle malibu    L6V 043
# ...

# %%
df.drop('origin',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    2
# model year      2
# car name        0
# CAR Number      7
# dtype: int64

# %%
df['acceleration'].median()
# Out:
# 14.0

# %%
df['acceleration'].replace(np.NAN,df['acceleration'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      2
# car name        0
# CAR Number      7
# dtype: int64

# %%
df['model year'].median()
# Out:
# 71.0

# %%
df['model year'].replace(np.NAN,df['model year'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# car name        0
# CAR Number      7
# dtype: int64

# %%
df['model year'] =df['model year'].astype(int)

# %%
df.dtypes
# Out:
# mpg               int64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# model year        int64
# car name         object
# CAR Number       object
# dtype: object

# %%
df['CAR Number'].replace(np.NAN,'Not Available',inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# car name        0
# CAR Number      0
# dtype: int64

# %%
df['CAR Number'].value_counts()
# Out:
# Not Available    7
# JHGY59           2
# TN5678           2
# L6V 043          1
# JH7485           1
#                 ..
# MGTE28           1
# HGVG69           1
# JHJGH38          1
# IUHU63G          1
# HUYT76           1
# Name: CAR Number, Length: 90, dtype: int64

# %%
df.drop_duplicates(subset=['CAR Number'], inplace=True)

# %%
df['CAR Number'].value_counts()
# Out:
# L6V 043    1
# JG7763     1
# SEE467     1
# MAST36     1
# BATE645    1
#           ..
# JHGY59     1
# JHJGH38    1
# IUHU63G    1
# HG4679     1
# HUYT76     1
# Name: CAR Number, Length: 90, dtype: int64

# %%
df.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0   18          8         307.0         130    3504          12.0          70
# 1   15          8         350.0         165    3693          11.5          70
# 2   18          8         318.0         150    3436          11.0          70
# 3   16          8         304.0         150    3433          12.0          70
# 4   17          8         302.0         140    3449          10.5          70
#
#                     car name CAR Number
# 0  chevrolet chevelle malibu    L6V 043
# 1          buick skylark 320     RTY079
# 2         plymouth satellite     MTP600
# 3              amc rebel sst     MNJ000
# 4                ford torino   JEETMEET

# %%
df.tail()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 93   14          8         318.0         150    4237          14.5
# 94   13          8         440.0         215    4735          11.0
# 95   12          8         455.0         225    4951          11.0
# 96   13          8         360.0         175    3821          11.0
# 97   18          6         225.0         105    3121          16.5
#
#     model year                      car name CAR Number
# 93          73      plymouth fury gran sedan     FGTEE4
# 94          73  chrysler new yorker brougham     GTTYR6
# 95          73      buick electra 225 custom    TTGGT53
# 96          73       amc ambassador brougham    TGTYY67
# 97          73              plymouth valiant     HUYT76

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'car name', 'CAR Number'],
#       dtype='object')

# %%
df.describe()
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# count  90.000000  90.000000     90.000000   90.000000    90.000000
# mean   18.133333   6.366667    259.516667  132.466667  3380.088889
# std     5.502196   1.863005    124.299937   47.763274   961.671714
# min     9.000000   3.000000     70.000000   46.000000  1773.000000
# 25%    14.000000   4.000000    121.000000   90.000000  2398.250000
# 50%    17.000000   8.000000    303.000000  140.000000  3442.500000
# 75%    22.750000   8.000000    351.000000  165.000000  4264.750000
# max    31.000000   8.000000    455.000000  225.000000  5140.000000
#
#        acceleration  model year
# count     90.000000   90.000000
# mean      13.955556   71.288889
# std        3.011816    1.051959
# min        8.000000   70.000000
# 25%       12.000000   70.000000
# 50%       13.500000   71.000000
# 75%       15.500000   72.000000
# max       23.500000   73.000000

# %%
df_max_hp = df[['horsepower', 'car name']].max()

# %%
df_max_hp
# Out:
# horsepower                225
# car name      volvo 145e (sw)
# dtype: object

# %%
df.loc[df['horsepower'] ==df['horsepower'].max()]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 8    14          8         455.0         225    4425          10.0
# 13   14          8         455.0         225    3086          10.0
# 95   12          8         455.0         225    4951          11.0
#
#     model year                  car name CAR Number
# 8           70          pontiac catalina    NMTL580
# 13          70   buick estate wagon (sw)     YUTN78
# 95          73  buick electra 225 custom    TTGGT53

# %%
df['mpg'] =235/df['mpg']

# %%
df
# Out:
#           mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   13.055556          8         307.0         130    3504          12.0
# 1   15.666667          8         350.0         165    3693          11.5
# 2   13.055556          8         318.0         150    3436          11.0
# 3   14.687500          8         304.0         150    3433          12.0
# 4   13.823529          8         302.0         140    3449          10.5
# ..        ...        ...           ...         ...     ...           ...
# 93  16.785714          8         318.0         150    4237          14.5
# 94  18.076923          8         440.0         215    4735          11.0
# 95  19.583333          8         455.0         225    4951          11.0
# 96  18.076923          8         360.0         175    3821          11.0
# 97  13.055556          6         225.0         105    3121          16.5
#
#     model year                      car name CAR Number
# ...

# %%
df.rename(columns={'mpg':'L/100KM'},inplace=True)

# %%
df
# Out:
#       L/100KM  cylinders  displacement  horsepower  weight  acceleration  \
# 0   13.055556          8         307.0         130    3504          12.0
# 1   15.666667          8         350.0         165    3693          11.5
# 2   13.055556          8         318.0         150    3436          11.0
# 3   14.687500          8         304.0         150    3433          12.0
# 4   13.823529          8         302.0         140    3449          10.5
# ..        ...        ...           ...         ...     ...           ...
# 93  16.785714          8         318.0         150    4237          14.5
# 94  18.076923          8         440.0         215    4735          11.0
# 95  19.583333          8         455.0         225    4951          11.0
# 96  18.076923          8         360.0         175    3821          11.0
# 97  13.055556          6         225.0         105    3121          16.5
#
#     model year                      car name CAR Number
# ...

# %%
df['weight'] =df['weight']/df['weight'].max()

# %%
df
# Out:
#       L/100KM  cylinders  displacement  horsepower    weight  acceleration  \
# 0   13.055556          8         307.0         130  0.681712          12.0
# 1   15.666667          8         350.0         165  0.718482          11.5
# 2   13.055556          8         318.0         150  0.668482          11.0
# 3   14.687500          8         304.0         150  0.667899          12.0
# 4   13.823529          8         302.0         140  0.671012          10.5
# ..        ...        ...           ...         ...       ...           ...
# 93  16.785714          8         318.0         150  0.824319          14.5
# 94  18.076923          8         440.0         215  0.921206          11.0
# 95  19.583333          8         455.0         225  0.963230          11.0
# 96  18.076923          8         360.0         175  0.743385          11.0
# 97  13.055556          6         225.0         105  0.607198          16.5
#
#     model year                      car name CAR Number
# ...

# %%
Label=['Low','Medium','high']
bins= np.linspace(min(df["horsepower"]),max(df["horsepower"]),4)
df["Horse_Power"]=pd.cut(df["horsepower"],bins,labels=Label,include_lowest=True)

# %%
df
# Out:
#       L/100KM  cylinders  displacement  horsepower    weight  acceleration  \
# 0   13.055556          8         307.0         130  0.681712          12.0
# 1   15.666667          8         350.0         165  0.718482          11.5
# 2   13.055556          8         318.0         150  0.668482          11.0
# 3   14.687500          8         304.0         150  0.667899          12.0
# 4   13.823529          8         302.0         140  0.671012          10.5
# ..        ...        ...           ...         ...       ...           ...
# 93  16.785714          8         318.0         150  0.824319          14.5
# 94  18.076923          8         440.0         215  0.921206          11.0
# 95  19.583333          8         455.0         225  0.963230          11.0
# 96  18.076923          8         360.0         175  0.743385          11.0
# 97  13.055556          6         225.0         105  0.607198          16.5
#
#     model year                      car name CAR Number Horse_Power
# ...

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot


# draw historgram of attribute "Horse_Power" with bins = 3
plt.pyplot.hist(df["Horse_Power"], bins = 3, edgecolor='black')

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
df['ZCyl'] = (df['cylinders'] - df['cylinders'].mean()) /df['cylinders'].std()

# %%
df
# Out:
#       L/100KM  cylinders  displacement  horsepower    weight  acceleration  \
# 0   13.055556          8         307.0         130  0.681712          12.0
# 1   15.666667          8         350.0         165  0.718482          11.5
# 2   13.055556          8         318.0         150  0.668482          11.0
# 3   14.687500          8         304.0         150  0.667899          12.0
# 4   13.823529          8         302.0         140  0.671012          10.5
# ..        ...        ...           ...         ...       ...           ...
# 93  16.785714          8         318.0         150  0.824319          14.5
# 94  18.076923          8         440.0         215  0.921206          11.0
# 95  19.583333          8         455.0         225  0.963230          11.0
# 96  18.076923          8         360.0         175  0.743385          11.0
# 97  13.055556          6         225.0         105  0.607198          16.5
#
# ...

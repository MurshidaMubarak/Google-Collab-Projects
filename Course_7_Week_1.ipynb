# %% [markdown]
# * Cities Activity

# %%
import pandas as pd

# %%
Data = pd.read_csv ('cities.csv')

# %%
Data.head ()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State"  Type
# 0        "Youngstown"       OH  None
# 1           "Yankton"       SD  None
# 2            "Yakima"       WA  None
# 3         "Worcester"       MA  None
# 4   "Wisconsin Dells"       WI  None

# %%
Data ['Type'] = None

# %%
Data.head ()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State"  Type
# 0        "Youngstown"       OH  None
# 1           "Yankton"       SD  None
# 2            "Yakima"       WA  None
# 3         "Worcester"       MA  None
# 4   "Wisconsin Dells"       WI  None

# %%
Data.describe
# Out:
# <bound method NDFrame.describe of      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"  Type
# 0          "Youngstown"       OH  None
# 1             "Yankton"       SD  None
# ...

# %%
Data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LatD      128 non-null    int64
#  1    "LatM"   128 non-null    int64
#  2    "LatS"   128 non-null    int64
#  3    "NS"     128 non-null    object
#  4    "LonD"   128 non-null    int64
#  5    "LonM"   128 non-null    int64
#  6    "LonS"   128 non-null    int64
#  7    "EW"     128 non-null    object
#  8    "City"   128 non-null    object
#  9    "State"  128 non-null    object
#  10  Type      0 non-null      object
# dtypes: int64(6), object(5)
# memory usage: 11.1+ KB

# %%
Data.to_csv ('cities.csv')

# %% [markdown]
# * Car Sale Activity

# %%
Cars = pd.read_excel ('CarSalesByModelStart.xlsx')
Cars.head ()
# Out:
#    Unnamed: 0  Year    Month                Date      Model  Dealer ID  \
# 0           0  2018  January 2018-01-01 23:00:00   Beaufort       1222
# 1           1  2018  January 2018-01-01 23:00:00     Salish       1222
# 2           2  2018  January 2018-01-01 23:00:00   Labrador       1222
# 3           3  2018  January 2018-01-01 23:00:00  Champlain       1222
# 4           4  2018  January 2018-01-01 23:00:00     Hudson       1222
#
#    Quantity Sold   Profit  Type
# 0             10  15000.0   NaN
# 1             13  39650.0   NaN
# 2             16  12800.0   NaN
# 3              3   6900.0   NaN
# 4             22  11000.0   NaN

# %%
Cars
# Out:
#       Unnamed: 0  Year     Month                Date      Model  Dealer ID  \
# 0              0  2018   January 2018-01-01 23:00:00   Beaufort       1222
# 1              1  2018   January 2018-01-01 23:00:00     Salish       1222
# 2              2  2018   January 2018-01-01 23:00:00   Labrador       1222
# 3              3  2018   January 2018-01-01 23:00:00  Champlain       1222
# 4              4  2018   January 2018-01-01 23:00:00     Hudson       1222
# ...          ...   ...       ...                 ...        ...        ...
# 1195        1195  2019  December 2019-12-01 23:00:00   Beaufort       1288
# 1196        1196  2019  December 2019-12-01 23:00:00     Salish       1288
# 1197        1197  2019  December 2019-12-01 23:00:00   Labrador       1288
# 1198        1198  2019  December 2019-12-01 23:00:00  Champlain       1288
# 1199        1199  2019  December 2019-12-01 23:00:00     Hudson       1288
#
#       Quantity Sold   Profit  Type
# ...

# %%
Cars ['Type'] = None

# %%
Cars.head ()
# Out:
#    Unnamed: 0  Year    Month                Date      Model  Dealer ID  \
# 0           0  2018  January 2018-01-01 23:00:00   Beaufort       1222
# 1           1  2018  January 2018-01-01 23:00:00     Salish       1222
# 2           2  2018  January 2018-01-01 23:00:00   Labrador       1222
# 3           3  2018  January 2018-01-01 23:00:00  Champlain       1222
# 4           4  2018  January 2018-01-01 23:00:00     Hudson       1222
#
#    Quantity Sold   Profit  Type
# 0             10  15000.0   NaN
# 1             13  39650.0   NaN
# 2             16  12800.0   NaN
# 3              3   6900.0   NaN
# 4             22  11000.0   NaN

# %%
Cars.describe ()
# Out:
#         Unnamed: 0         Year    Dealer ID  Quantity Sold        Profit  \
# count  1200.000000  1200.000000  1200.000000     1200.00000   1200.000000
# mean    599.500000  2018.500000  1281.800000       17.99750  24974.055208
# std     346.554469     0.500208    72.453672        9.97432  17370.750612
# min       0.000000  2018.000000  1212.000000        2.00000   4600.000000
# 25%     299.750000  2018.000000  1217.000000       11.00000  13500.000000
# 50%     599.500000  2018.500000  1256.000000       18.00000  18500.000000
# 75%     899.250000  2019.000000  1336.000000       24.00000  28922.812500
# max    1199.000000  2019.000000  1402.000000       48.00000  83875.000000
#
#        Type
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN

# %%
Cars.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           1200 non-null   int64
#  1   Month          1200 non-null   object
#  2   Date           1200 non-null   datetime64[ns]
#  3   Model          1200 non-null   object
#  4   Dealer ID      1200 non-null   int64
#  5   Quantity Sold  1200 non-null   int64
#  6   Profit         1200 non-null   float64
#  7   Type           0 non-null      object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 75.1+ KB

# %%
Cars.to_excel ('CarSalesByModelStart.xlsx')

# %% [markdown]
# * Jay.JSON Activity

# %%
Jsonf = pd.read_json ('Jay (1).json')

# %%
Jsonf
# Out:
#      Duration  Pulse  Maxpulse  Calories  Type
# 0          60    110       130     409.1  None
# 1          60    117       145     479.0  None
# 2          60    103       135     340.0  None
# 3          45    109       175     282.4  None
# 4          45    117       148     406.0  None
# ..        ...    ...       ...       ...   ...
# 164        60    105       140     290.8  None
# 165        60    110       145     300.4  None
# 166        60    115       145     310.2  None
# 167        75    120       150     320.4  None
# 168        75    125       150     330.4  None
#
# [169 rows x 5 columns]

# %%
Jsonf ['Type'] = None

# %%
Jsonf.head ()
# Out:
#    Duration  Pulse  Maxpulse  Calories  Type
# 0        60    110       130     409.1  None
# 1        60    117       145     479.0  None
# 2        60    103       135     340.0  None
# 3        45    109       175     282.4  None
# 4        45    117       148     406.0  None

# %%
Jsonf.describe ()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.800000
# std     42.299949   14.510259   16.450434   266.377134
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
Jsonf.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
#  4   Type      0 non-null      object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 7.9+ KB

# %%
Jsonf.to_json ('Jay(1).Json')

# %% [markdown]
# * GoodBelly Activity

# %%
Belly = pd.read_excel ('GoodBelly-DataSet.xlsx')

# %%
Belly
# Out:
#            Date Region                    Store  Units Sold  \
# 0    2010-05-04     FL  Biscayne (aka Aventura)  150.702088
# 1    2010-05-11     FL  Biscayne (aka Aventura)  197.403797
# 2    2010-05-18     FL  Biscayne (aka Aventura)  235.106172
# 3    2010-05-25     FL  Biscayne (aka Aventura)  226.692427
# 4    2010-06-01     FL  Biscayne (aka Aventura)  257.688151
# ...         ...    ...                      ...         ...
# 1381 2010-06-15     SW                 Veterans  192.685157
# 1382 2010-06-22     SW                 Veterans  173.720882
# 1383 2010-06-29     SW                 Veterans  278.582872
# 1384 2010-07-06     SW                 Veterans  122.229768
# 1385 2010-07-13     SW                 Veterans  166.893026
#
#       Average Retail Price  Sales Rep  Endcap  Demo  Demo1-3  Demo4-5  \
# 0                 4.390000          0       0     0        0        0
# 1                 3.997692          0       0     0        0        0
# ...

# %%
Belly.size
# Out:
# 16632

# %%
Belly.dtypes
# Out:
# Date                    datetime64[ns]
# Region                          object
# Store                           object
# Units Sold                     float64
# Average Retail Price           float64
# Sales Rep                        int64
# Endcap                           int64
# Demo                             int64
# Demo1-3                          int64
# Demo4-5                          int64
# Natural                          int64
# Fitness                          int64
# dtype: object

# %%
Belly.describe()
# Out:
#         Units Sold  Average Retail Price    Sales Rep       Endcap  \
# count  1386.000000           1386.000000  1386.000000  1386.000000
# mean    253.820718              4.107093     0.549784     0.038240
# std     110.998731              0.463828     0.497695     0.191843
# min      47.559852              2.889286     0.000000     0.000000
# 25%     189.995471              3.775714     0.000000     0.000000
# 50%     236.735266              4.096667     1.000000     0.000000
# 75%     295.804391              4.425067     1.000000     0.000000
# max    1041.200256              6.251538     1.000000     1.000000
#
#               Demo      Demo1-3      Demo4-5      Natural      Fitness
# count  1386.000000  1386.000000  1386.000000  1386.000000  1386.000000
# mean      0.058442     0.156566     0.075758     1.448773     2.476190
# std       0.234661     0.363522     0.264705     0.975092     1.592789
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %%
Belly.head(50).describe()
# Out:
#        Units Sold  Average Retail Price  Sales Rep     Endcap  Demo  Demo1-3  \
# count   50.000000             50.000000       50.0  50.000000  50.0     50.0
# mean   186.280727              4.128036        0.0   0.100000   0.0      0.0
# std     50.359675              0.265949        0.0   0.303046   0.0      0.0
# min    103.319023              3.690000        0.0   0.000000   0.0      0.0
# 25%    143.032357              3.901779        0.0   0.000000   0.0      0.0
# 50%    195.163343              4.082833        0.0   0.000000   0.0      0.0
# 75%    223.182062              4.371250        0.0   0.000000   0.0      0.0
# max    306.793819              4.643846        0.0   1.000000   0.0      0.0
#
#          Demo4-5    Natural    Fitness
# count  50.000000  50.000000  50.000000
# mean    0.040000   1.300000   1.560000
# std     0.197949   1.015191   1.430855
# min     0.000000   0.000000   0.000000
# 25%     0.000000   1.000000   1.000000
# ...
